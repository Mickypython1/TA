# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install -c conda-forge cartopy
# !pip install xarray[complete] pythia-datasets cftime
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Requirement already satisfied: pythia-datasets in /usr/local/lib/python3.11/site-packages (2026.2.20)
# Requirement already satisfied: cftime in /usr/local/lib/python3.11/site-packages (1.6.5)
# Requirement already satisfied: xarray[complete] in /usr/local/lib/python3.11/site-packages (2026.2.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (2.4.2)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (24.2)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (3.0.1)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/site-packages (from pythia-datasets) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas>=2.2->xarray[complete]) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from pooch->pythia-datasets) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/site-packages (from pooch->pythia-datasets) (2.32.3)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (1.17.1)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (1.6.0)
# Requirement already satisfied: numbagg>=0.8 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (0.9.4)
# Requirement already satisfied: numba>=0.62 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (0.64.0)
# Requirement already satisfied: flox>=0.9 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (0.11.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (3.4.0)
# Requirement already satisfied: netCDF4>=1.6.0 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (1.7.4)
# Requirement already satisfied: h5netcdf>=1.4.0 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (1.8.1)
# Requirement already satisfied: pydap in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (3.5.9)
# Requirement already satisfied: zarr>=2.18 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (2026.2.0)
# Requirement already satisfied: sparse>=0.15 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (0.18.0)
# Requirement already satisfied: dask[complete] in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (2026.1.2)
# Requirement already satisfied: cartopy>=0.23 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (0.25.0)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (3.10.8)
# Requirement already satisfied: nc-time-axis in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (1.4.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/site-packages (from xarray[complete]) (0.13.2)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.11/site-packages (from cartopy>=0.23->xarray[complete]) (2.1.2)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.11/site-packages (from cartopy>=0.23->xarray[complete]) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.11/site-packages (from cartopy>=0.23->xarray[complete]) (3.7.1)
# Requirement already satisfied: numpy_groupies>=0.9.19 in /usr/local/lib/python3.11/site-packages (from flox>=0.9->xarray[complete]) (0.11.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/site-packages (from flox>=0.9->xarray[complete]) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.8->xarray[complete]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.8->xarray[complete]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.8->xarray[complete]) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.8->xarray[complete]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.8->xarray[complete]) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.8->xarray[complete]) (3.3.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/site-packages (from netCDF4>=1.6.0->xarray[complete]) (2026.2.25)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /usr/local/lib/python3.11/site-packages (from numba>=0.62->xarray[complete]) (0.46.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray[complete]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.19.0->pooch->pythia-datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.19.0->pooch->pythia-datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.19.0->pooch->pythia-datasets) (2.3.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.11/site-packages (from zarr>=2.18->xarray[complete]) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.11/site-packages (from zarr>=2.18->xarray[complete]) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.11/site-packages (from zarr>=2.18->xarray[complete]) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.9 in /usr/local/lib/python3.11/site-packages (from zarr>=2.18->xarray[complete]) (4.15.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (3.1.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (6.0.3)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (8.7.1)
# Requirement already satisfied: pyarrow>=16.0 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (23.0.1)
# Requirement already satisfied: lz4>=4.3.2 in /usr/local/lib/python3.11/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (4.4.5)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.11/site-packages (from pydap->xarray[complete]) (1.3.1)
# Requirement already satisfied: Webob in /usr/local/lib/python3.11/site-packages (from pydap->xarray[complete]) (1.8.9)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (from pydap->xarray[complete]) (4.14.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/site-packages (from pydap->xarray[complete]) (6.0.2)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.11/site-packages (from pydap->xarray[complete]) (3.1.6)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask[complete]; extra == "parallel"->xarray[complete]) (3.23.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/site-packages (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[complete]) (1.0.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4->pydap->xarray[complete]) (2.8.3)
# Requirement already satisfied: distributed<2026.1.3,>=2026.1.2 in /usr/local/lib/python3.11/site-packages (from dask[complete]->xarray[complete]) (2026.1.2)
# Requirement already satisfied: bokeh>=3.1.0 in /usr/local/lib/python3.11/site-packages (from dask[complete]->xarray[complete]) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from Jinja2->pydap->xarray[complete]) (3.0.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/site-packages (from requests-cache->pydap->xarray[complete]) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/site-packages (from requests-cache->pydap->xarray[complete]) (26.1.0)
# Requirement already satisfied: url-normalize>=2.0 in /usr/local/lib/python3.11/site-packages (from requests-cache->pydap->xarray[complete]) (2.2.1)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.11/site-packages (from bokeh>=3.1.0->dask[complete]->xarray[complete]) (2.18.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/site-packages (from bokeh>=3.1.0->dask[complete]->xarray[complete]) (6.5.5)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/site-packages (from bokeh>=3.1.0->dask[complete]->xarray[complete]) (2025.11.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/site-packages (from distributed<2026.1.3,>=2026.1.2->dask[complete]->xarray[complete]) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/site-packages (from distributed<2026.1.3,>=2026.1.2->dask[complete]->xarray[complete]) (7.2.2)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.11/site-packages (from distributed<2026.1.3,>=2026.1.2->dask[complete]->xarray[complete]) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in /usr/local/lib/python3.11/site-packages (from distributed<2026.1.3,>=2026.1.2->dask[complete]->xarray[complete]) (3.2.2)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.11/site-packages (from distributed<2026.1.3,>=2026.1.2->dask[complete]->xarray[complete]) (3.0.0)

# %% [markdown]
# # Calculating ENSO with Xarray

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# In this tutorial, we perform and demonstrate the following tasks:
#
# 1. Load SST data from the CESM2 model
# 2. Mask data using `.where()`
# 3. Compute climatologies and anomalies using `.groupby()`
# 4. Use `.rolling()` to compute moving average
# 5. Compute, normalize, and plot the Niño 3.4 Index

# %% [markdown]
# ## Prerequisites
#
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | [Introduction to Xarray](xarray-intro) | Necessary | {cite:t}`hoyer2017xarray` |
# | [Computation and Masking](computation-masking) | Necessary | |
#
#
#
# - **Time to learn**: 20 minutes

# %% [markdown]
# ---

# %% [markdown]
# ## Imports
#
# For this tutorial, we import several Python packages. As plotting ENSO data requires a geographically accurate map, Cartopy is imported to handle geographic features and map projections. Xarray is used to manage raw data, and Matplotlib allows for feature-rich data plotting. Finally, a custom Pythia package is imported, in this case allowing access to the Pythia example data library.

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import xarray as xr
from pythia_datasets import DATASETS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3855/4147536874.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 import xarray as xr
# ----> 3 from pythia_datasets import DATASETS
#
# ModuleNotFoundError: No module named 'pythia_datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## The Niño 3.4 Index

# %% [markdown]
# In this tutorial, we combine topics covered in previous Xarray tutorials to demonstrate a real-world example. The real-world scenario demonstrated in this tutorial is the computation of the [Niño 3.4 Index](https://climatedataguide.ucar.edu/climate-data/nino-sst-indices-nino-12-3-34-4-oni-and-tni), as shown in the CESM2 submission for the [CMIP6 project](https://esgf-node.llnl.gov/projects/cmip6/). A rough definition of Niño 3.4, in addition to a definition of Niño data computation, is listed below:
#
# > Niño 3.4 (5N-5S, 170W-120W): The Niño 3.4 anomalies may be thought of as representing the average equatorial SSTs across the Pacific from about the dateline to the South American coast. The Niño 3.4 index typically uses a 5-month running mean, and El Niño or La Niña events are defined when the Niño 3.4 SSTs exceed +/- 0.4C for a period of six months or more.
#
# > Niño X Index computation: a) Compute area averaged total SST from Niño X region; b) Compute monthly climatology (e.g., 1950-1979) for area averaged total SST from Niño X region, and subtract climatology from area averaged total SST time series to obtain anomalies; c) Smooth the anomalies with a 5-month running mean; d) Normalize the smoothed values by its standard deviation over the climatological period.
#
# ![](https://www.ncdc.noaa.gov/monitoring-content/teleconnections/nino-regions.gif)
#
# The overall goal of this tutorial is to produce a plot of ENSO data using Xarray; this plot will resemble the Oceanic Niño Index plot shown below.
#
# ![ONI index plot from NCAR Climate Data Guide](https://climatedataguide.ucar.edu/sites/default/files/styles/extra_large/public/2022-03/indices_oni_2_2_lg.png)

# %% [markdown]
# In this first example, we begin by opening datasets containing the sea-surface temperature (SST) and grid-cell size data. (These datasets are taken from the Pythia example data library, using the Pythia package imported above.) The two datasets are then combined into a single dataset using Xarray's `merge` method.

# %%
filepath = DATASETS.fetch('CESM2_sst_data.nc')
data = xr.open_dataset(filepath)
filepath2 = DATASETS.fetch('CESM2_grid_variables.nc')
areacello = xr.open_dataset(filepath2).areacello

ds = xr.merge([data, areacello])
ds

# %% [markdown]
# This example uses Matplotlib and Cartopy to plot the first time slice of the dataset on an actual geographic map. By doing so, we verify that the data values fit the pattern of SST data:

# %%
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson(central_longitude=180))
ax.coastlines()
ax.gridlines()
ds.tos.isel(time=0).plot(
    ax=ax, transform=ccrs.PlateCarree(), vmin=-2, vmax=30, cmap='coolwarm'
);

# %% [markdown]
# ## Select the Niño 3.4 region
#
# In this set of examples, we demonstrate the selection of data values from a dataset which are located in the Niño 3.4 geographic region. The following example illustrates a selection technique that uses the `sel()` or `isel()` method:

# %%
tos_nino34 = ds.sel(lat=slice(-5, 5), lon=slice(190, 240))
tos_nino34

# %% [markdown]
# This example illustrates the alternate technique for selecting Niño 3.4 data, which makes use of the `where()` method:

# %%
tos_nino34 = ds.where(
    (ds.lat < 5) & (ds.lat > -5) & (ds.lon > 190) & (ds.lon < 240), drop=True
)
tos_nino34

# %% [markdown]
# Finally, we plot the selected region to ensure it fits the definition of the Niño 3.4 region:

# %%
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson(central_longitude=180))
ax.coastlines()
ax.gridlines()
tos_nino34.tos.isel(time=0).plot(
    ax=ax, transform=ccrs.PlateCarree(), vmin=-2, vmax=30, cmap='coolwarm'
)
ax.set_extent((120, 300, 10, -10))

# %% [markdown]
# ## Compute the anomalies
#
# There are three main steps to obtain the anomalies from the Niño 3.4 dataset created in the previous set of examples. First, we use the `groupby()` method to convert to monthly data. Second, we subtract the mean sea-surface temperature (SST) from the monthly data. Finally, we obtain the anomalies by computing a weighted average. These steps are illustrated in the next example:

# %%
gb = tos_nino34.tos.groupby('time.month')
tos_nino34_anom = gb - gb.mean(dim='time')
index_nino34 = tos_nino34_anom.weighted(tos_nino34.areacello).mean(dim=['lat', 'lon'])

# %% [markdown]
# In this example, we smooth the data curve by applying a `mean` function with a 5-month moving window to the anomaly dataset. We then plot the smoothed data against the original data to demonstrate:

# %%
index_nino34_rolling_mean = index_nino34.rolling(time=5, center=True).mean()

# %%
index_nino34.plot(size=8)
index_nino34_rolling_mean.plot()
plt.legend(['anomaly', '5-month running mean anomaly'])
plt.title('SST anomaly over the Niño 3.4 region');

# %% [markdown]
# Since the ENSO index conveys deviations from a norm, the calculation of Niño data requires a standard deviation. In this example, we calculate the standard deviation of the SST in the Niño 3.4 region data, across the entire time period of the data array:

# %%
std_dev = tos_nino34.tos.std()
std_dev

# %% [markdown]
# The final step of the Niño 3.4 index calculation involves normalizing the data. In this example, we perform this normalization by dividing the smoothed anomaly data by the standard deviation calculated above:

# %%
normalized_index_nino34_rolling_mean = index_nino34_rolling_mean / std_dev

# %% [markdown]
# ## Visualize the computed Niño 3.4 index

# %% [markdown]
# In this example, we use Matplotlib to generate a plot of our final Niño 3.4 data. This plot is set up to highlight values above 0.5, corresponding to El Niño (warm) events, and values below -0.5, corresponding to La Niña (cold) events.

# %%
fig = plt.figure(figsize=(12, 6))

plt.fill_between(
    normalized_index_nino34_rolling_mean.time.data,
    normalized_index_nino34_rolling_mean.where(
        normalized_index_nino34_rolling_mean >= 0.4
    ).data,
    0.4,
    color='red',
    alpha=0.9,
)
plt.fill_between(
    normalized_index_nino34_rolling_mean.time.data,
    normalized_index_nino34_rolling_mean.where(
        normalized_index_nino34_rolling_mean <= -0.4
    ).data,
    -0.4,
    color='blue',
    alpha=0.9,
)

normalized_index_nino34_rolling_mean.plot(color='black')
plt.axhline(0, color='black', lw=0.5)
plt.axhline(0.4, color='black', linewidth=0.5, linestyle='dotted')
plt.axhline(-0.4, color='black', linewidth=0.5, linestyle='dotted')
plt.title('Niño 3.4 Index');

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# This tutorial covered the use of Xarray features, including selection, grouping, and statistical functions, to compute and visualize a data index important to climate science.

# %% [markdown]
# ## Additional Resources
#
# - [Niño 3.4 index](https://climatedataguide.ucar.edu/climate-data/nino-sst-indices-nino-12-3-34-4-oni-and-tni)
# - [Matplotlib's `fill_between` method](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.fill_between.html)
# - [Matplotlib's `axhline` method](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axhline.html) (see also its analogous `axvline` method)
